# %% [markdown]
# # 3 - B: Training a Word2Vec Model
#
# ## 목표
# - 한국어 단어 임베딩 벡터를 Word2Vec을 학습시켜 얻어봅시다.
# - 학습데이터로는 [네이버 영화리뷰 데이터](https://drive.google.com/file/d/1eEWFL-vKGP5pReH8dxD1KvtR6f0BfTqS/view?usp=sharing)를 사용해볼 것입니다.

# %%
# install the libraries needed
# !pip3 install gensim  # word2vec 훈련을 위해
# !pip3 install requests # 데이터 다운로드를 위해
# !pip3 install pandas # 데이터 시각화를 위해
# !pip3 install konlpy  # 한국어 형태소 분석을 위해
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (3.6.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (5.1.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.19.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.1.5)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Collecting konlpy
#   Downloading konlpy-0.5.2-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 1.3 MB/s
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting beautifulsoup4==4.6.0
#   Downloading beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 5.0 MB/s
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 30.5 MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.5.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Installing collected packages: JPype1, colorama, beautifulsoup4, konlpy
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.3.0 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2

# %%
# import the libraries needed
from gensim.models.word2vec import Word2Vec
from gensim.models.callbacks import CallbackAny2Vec
from konlpy.tag import Okt
from typing import List
import pandas as pd
from tqdm import tqdm
import gdown
# --- Word2Vec 훈련이 진행되는 과정을 모니터링 하기 위해, 모든 로깅 레벨을 INFO로 올려줍니다. --- #
from sys import stdout
import logging
logging.basicConfig(stream=stdout, level=logging.DEBUG)

# %%
# --- 데이터 다운로드를 위한 코드; 수정하지 말아주세요! --- #
NAVER_REVIEWS_TSV_URL = "https://drive.google.com/u/0/uc?id=1eEWFL-vKGP5pReH8dxD1KvtR6f0BfTqS&export=download"
NAVER_REVIEWS_TSV = "./naver_reviews.tsv"
# 드라이브에 업로드한 (data/naver_reviews.tsv) 파일을 로컬에 다운로드
gdown.download(url=NAVER_REVIEWS_TSV_URL, output=NAVER_REVIEWS_TSV, quiet=False)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): drive.google.com:443
# DEBUG:urllib3.connectionpool:https://drive.google.com:443 "GET /u/0/uc?id=1eEWFL-vKGP5pReH8dxD1KvtR6f0BfTqS&export=download HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): doc-0o-08-docs.googleusercontent.com:443
# DEBUG:urllib3.connectionpool:https://doc-0o-08-docs.googleusercontent.com:443 "GET /docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/q2tlcghsgkhtpvcd5k05spgj2vcp86o9/1629627375000/11244659521636006499/*/1eEWFL-vKGP5pReH8dxD1KvtR6f0BfTqS?e=download HTTP/1.1" 200 None
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1eEWFL-vKGP5pReH8dxD1KvtR6f0BfTqS&export=download
# To: /content/naver_reviews.tsv
# 19.5MB [00:00, 147MB/s]
# './naver_reviews.tsv'

# %%
# 네이버 영화 데이터를 pandas dataframe으로 로드합니다. 구분자가 \t 인 tsv 파일을 읽어야 하니, sep="\t"로 넣어줍니다.
reviews_df = pd.read_csv(NAVER_REVIEWS_TSV, sep="\t")

# %%
# (id, 리뷰, 긍정=1/부정=0)으로 구성된 데이터입니다.
reviews_df.head(10)  # 상위 10개 문서 출력
# Out:
#          id                                           document  label
# 0   8112052                                어릴때보고 지금다시봐도 재밌어요ㅋㅋ      1
# 1   8132799  디자인을 배우는 학생으로, 외국디자이너와 그들이 일군 전통을 통해 발전해가는 문화산...      1
# 2   4655635               폴리스스토리 시리즈는 1부터 뉴까지 버릴께 하나도 없음.. 최고.      1
# 3   9251303  와.. 연기가 진짜 개쩔구나.. 지루할거라고 생각했는데 몰입해서 봤다.. 그래 이런...      1
# 4  10067386                        안개 자욱한 밤하늘에 떠 있는 초승달 같은 영화.      1
# 5   2190435                      사랑을 해본사람이라면 처음부터 끝까지 웃을수 있는영화      1
# 6   9279041                                   완전 감동입니다 다시봐도 감동      1
# 7   7865729                        개들의 전쟁2 나오나요? 나오면 1빠로 보고 싶음      1
# 8   7477618                                                  굿      1
# 9   9250537                                     바보가 아니라 병 쉰 인듯      1

# %%
# 각 모든 데이터 중에, 결측치가 하나라도 존재하는지 확인해볼게요.
# df.info(): https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html
print(reviews_df.isnull().values.any())
reviews_df.info()
# Out:
# True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        200000 non-null  int64
#  1   document  199992 non-null  object
#  2   label     200000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 4.6+ MB

# %%
# document 컬럼을 보아하니, 결측치가 조금 있습니다. 결측치를 제거하기 위해 dropna()를 사용하겠습니다.
# df.dropna() 문서: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html
# how = any 로 설정할 경우? null인 컬럼이 하나라도 있으면 해당 row를 드랍.
# how = all 로 설정할 경우? 모든 컬럼이 null 일 경우에만 해당 row를 드랍.
reviews_df = reviews_df.dropna(how="any")
print(reviews_df.isnull().values.any())
reviews_df.info()
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# False
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199992 entries, 0 to 199999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        199992 non-null  int64
#  1   document  199992 non-null  object
#  2   label     199992 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 6.1+ MB

# %%
# ---- 전체 리뷰문서 토크나이징을 진행합니다 --- # 
okt = Okt()  # okt 형태소 분석기를 토크나이저로 사용합니다.
corpus: List[List[str]] = list()
# 모든 데이터를 다 토크나이즈를 하기에는 시간이 많이 걸릴 것입니다. 
# 앞 10만개 정도만 선택하여 토크나이즈를 해보도록 하겠습니다.
reviews_df = reviews_df[:100000] 
for sent in tqdm(reviews_df['document'], "tokenization in progress"):
    # 토큰화를 진행할 때, 어근을 추출하여 토큰화 동시에 정규화를 해줍니다 (e.g. 밝은 -> 밝다)
    tokens = okt.morphs(sent, stem=True) 
    corpus.append(tokens)
# Out:
# tokenization in progress: 100%|██████████| 100000/100000 [05:06<00:00, 326.02it/s]

# %%
# --- 전처리된 말뭉치 확인 --- #
# 대부분의 단어들이 정규화되어, "-다"로 끝나는 것을 확인해볼 수 있습니다. 
for tokens in corpus[:10]:
  print(tokens)
# Out:
# ['어리다', '때', '보고', '지금', '다시', '보다', '재밌다', 'ㅋㅋ']
# ['디자인', '을', '배우다', '학생', '으로', ',', '외국', '디자이너', '와', '그', '들', '이', '일군', '전통', '을', '통해', '발전', '하다', '문화', '산업', '이', '부럽다', '.', '사실', '우리나라', '에서도', '그', '어렵다', '시절', '에', '끝', '까지', '열정', '을', '지키다', '노라노', '같다', '전통', '이', '있다', '저', '와', '같다', '사람', '들', '이', '꿈', '을', '꾸다', '이루다', '나가다', '수', '있다', '것', '에', '감사하다', '.']
# ['폴리스스토리', '시리즈', '는', '1', '부터', '뉴', '까지', '버리다', '하나', '도', '없다', '..', '최고', '.']
# ['오다', '..', '연기', '가', '진짜', '개', '쩔다', '..', '지루하다', '생각', '하다', '몰입', '하다', '보다', '..', '그렇다', '이렇다', '진짜', '영화', '지']
# ['안개', '자욱하다', '밤하늘', '에', '뜨다', '있다', '초승달', '같다', '영화', '.']
# ['사랑', '을', '해보다', '사람', '이', '라면', '처음', '부터', '끝', '까지', '웃다', '있다', '영화']
# ['완전', '감동', '이다', '다시', '보다', '감동']
# ['개', '들', '의', '전쟁', '2', '나오다', '?', '나오다', '1', '빠', '로', '보고', '싶다']
# ['굿']
# ['바보', '가', '아니다', '병', '쉰', '이다']

# %%
# --- 워드 투 벡터의 훈련상황을 모니터링하기 위해, 메 에폭마다 모델의 로스 (error)를 출력해볼 수 있습니다. --- #
# 이를 위해서 Callback이라는 객체를 사용할 수 있습니다. 
# https://stackoverflow.com/a/54891714
class LossCallBack(CallbackAny2Vec):
    def __init__(self):
        self.epoch = 0
        self.losses = list()  # collect losses here
        self.losses.append(0.0)

    def on_epoch_end(self, model):
        """
        이 함수는 매 에폭의 마지막 단계에 호출됩니다.
        """
        # get_latest_training_loss는 현재까지의 cumulative loss를 출력합니다.
        loss = model.get_latest_training_loss()
        self.epoch += 1
        self.losses.append(loss)
        # 현재까지의 축적된 로스의 총합을 리포트
        print('Cumulative loss after epoch {}: {}'.format(self.epoch, loss))
        # 바로 이전 로스와의 차이도 리포트
        print('Offset to previous loss: {}'.format(str(self.losses[-1] - self.losses[-2])))

# %%
# --- TODO 1 --- # 
# Word2Vec의 객체를 생성하면, 바로 Word2Vec 모델의 학습이 진행됩니다. 
# Word2Vec 클래스 문서를 참고하여: https://radimrehurek.com/gensim/models/word2vec.html#gensim.models.word2vec.Word2Vec
# Word2Vec 모델학습을 시작해보세요!
# 하이퍼파라미터는 다음과 같이 설정해주세요:
# alpha (learning rate) = 0.01
# window (윈도우의 길이) = 6
# min_count (학습할 단어의 최소 빈도수) = 3
# sg (skipgram 사용여부) =  1
# iter (에폭) = 50
# compute_loss (매 에폭마다 로스 계산) = True
# callbacks (매 에폭마다 호출할 것들) = (LossCallBack(),)
# negative = 5 (이웃이 아닌 단어를 몇개 샘플링 할거니?)
model = Word2Vec(sentences=corpus,
                 alpha=0.01,
                 window=6,
                 min_count=3,
                 sg=1,
                 iter=50,
                 compute_loss=True, 
                 callbacks=(LossCallBack(), ))
# ------------ #
# Out:
# INFO:gensim.models.word2vec:collecting all words and their counts
# INFO:gensim.models.word2vec:PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #10000, processed 139027 words, keeping 12618 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #20000, processed 281908 words, keeping 18275 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #30000, processed 420918 words, keeping 22279 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #40000, processed 560545 words, keeping 25579 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #50000, processed 700594 words, keeping 28656 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #60000, processed 841566 words, keeping 31336 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #70000, processed 982494 words, keeping 33685 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #80000, processed 1124238 words, keeping 35890 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #90000, processed 1263421 words, keeping 37919 word types
# INFO:gensim.models.word2vec:collected 39823 word types from a corpus of 1402998 raw words and 100000 sentences
# INFO:gensim.models.word2vec:Loading a fresh vocabulary
# INFO:gensim.models.word2vec:effective_min_count=3 retains 16154 unique words (40% of original 39823, drops 23669)
# INFO:gensim.models.word2vec:effective_min_count=3 leaves 1374103 word corpus (97% of original 1402998, drops 28895)
# INFO:gensim.models.word2vec:deleting the raw counts dictionary of 39823 items
# INFO:gensim.models.word2vec:sample=0.001 downsamples 55 most-common words
# INFO:gensim.models.word2vec:downsampling leaves estimated 1077343 word corpus (78.4% of prior 1374103)
# INFO:gensim.models.base_any2vec:estimated required memory for 16154 words and 100 dimensions: 21000200 bytes
# INFO:gensim.models.word2vec:resetting layer weights
# INFO:gensim.models.base_any2vec:training model with 3 workers on 16154 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=6
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 16.38% examples, 168605 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 32.76% examples, 171222 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 49.89% examples, 173997 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 66.91% examples, 174768 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 1 - PROGRESS: at 83.93% examples, 175860 words/s, in_qsize 4, out_qsize 1
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 1 : training on 1402998 raw words (1077132 effective words) took 6.1s, 177921 effective words/s
# Cumulative loss after epoch 1: 5456080.0
# Offset to previous loss: 5456080.0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 15.71% examples, 165962 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 32.75% examples, 172196 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 49.16% examples, 172990 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 65.50% examples, 173100 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 2 - PROGRESS: at 83.23% examples, 175326 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 2 : training on 1402998 raw words (1077001 effective words) took 6.1s, 176419 effective words/s
# Cumulative loss after epoch 2: 9390075.0
# Offset to previous loss: 3933995.0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 15.67% examples, 167206 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 32.03% examples, 169700 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 49.89% examples, 176608 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 67.59% examples, 176137 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 3 - PROGRESS: at 84.64% examples, 176674 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 3 : training on 1402998 raw words (1076569 effective words) took 6.1s, 176987 effective words/s
# Cumulative loss after epoch 3: 12569494.0
# Offset to previous loss: 3179419.0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 16.38% examples, 174732 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 33.48% examples, 176827 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 50.62% examples, 176248 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 68.32% examples, 176667 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 4 - PROGRESS: at 85.32% examples, 177443 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 4 : training on 1402998 raw words (1077799 effective words) took 6.0s, 178393 effective words/s
# Cumulative loss after epoch 4: 15787085.0
# Offset to previous loss: 3217591.0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 16.39% examples, 168922 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 33.50% examples, 173906 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 50.62% examples, 177035 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 66.90% examples, 175982 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 5 - PROGRESS: at 83.95% examples, 177465 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 5 : training on 1402998 raw words (1077196 effective words) took 6.1s, 177950 effective words/s
# Cumulative loss after epoch 5: 18949458.0
# Offset to previous loss: 3162373.0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 16.38% examples, 170994 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 33.48% examples, 170613 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 52.08% examples, 173962 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 69.03% examples, 174832 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 6 - PROGRESS: at 86.73% examples, 175591 words/s, in_qsize 4, out_qsize 1
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 6 : training on 1402998 raw words (1076637 effective words) took 6.1s, 177736 effective words/s
# Cumulative loss after epoch 6: 22111682.0
# Offset to previous loss: 3162224.0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 16.39% examples, 166121 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 33.48% examples, 170423 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 49.89% examples, 171912 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 66.91% examples, 173676 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 7 - PROGRESS: at 84.61% examples, 174369 words/s, in_qsize 5, out_qsize 1
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 7 : training on 1402998 raw words (1077008 effective words) took 6.1s, 176716 effective words/s
# Cumulative loss after epoch 7: 25312254.0
# Offset to previous loss: 3200572.0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 16.38% examples, 171517 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 33.47% examples, 172643 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 51.29% examples, 175315 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 69.02% examples, 179161 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 8 - PROGRESS: at 85.32% examples, 177883 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 8 : training on 1402998 raw words (1077168 effective words) took 6.0s, 178733 effective words/s
# Cumulative loss after epoch 8: 28443248.0
# Offset to previous loss: 3130994.0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 15.71% examples, 165747 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 32.76% examples, 173375 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 49.88% examples, 175734 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 66.90% examples, 177172 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 9 - PROGRESS: at 83.93% examples, 178444 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 9 : training on 1402998 raw words (1077892 effective words) took 6.0s, 178822 effective words/s
# Cumulative loss after epoch 9: 31692608.0
# Offset to previous loss: 3249360.0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 16.38% examples, 174141 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 33.48% examples, 177577 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 50.60% examples, 178795 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 67.59% examples, 176769 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 10 - PROGRESS: at 84.61% examples, 176843 words/s, in_qsize 6, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 10 : training on 1402998 raw words (1077194 effective words) took 6.0s, 178890 effective words/s
# Cumulative loss after epoch 10: 34278540.0
# Offset to previous loss: 2585932.0
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 14.98% examples, 160464 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 32.76% examples, 175143 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 49.16% examples, 174430 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 66.20% examples, 176480 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 83.23% examples, 176710 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:EPOCH 11 - PROGRESS: at 100.00% examples, 177186 words/s, in_qsize 0, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 11 : training on 1402998 raw words (1077620 effective words) took 6.1s, 176950 effective words/s
# Cumulative loss after epoch 11: 36024188.0
# Offset to previous loss: 1745648.0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 15.71% examples, 167371 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 32.76% examples, 172755 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 49.89% examples, 173101 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 66.20% examples, 173092 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 12 - PROGRESS: at 83.93% examples, 175238 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:EPOCH - 12 : training on 1402998 raw words (1077176 effective words) took 6.1s, 176944 effective words/s
# Cumulative loss after epoch 12: 37758824.0
# Offset to previous loss: 1734636.0
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 17.07% examples, 179428 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 34.18% examples, 178000 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 51.34% examples, 179559 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 70.44% examples, 183051 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 13 - PROGRESS: at 87.50% examples, 183160 words/s, in_qsize 6, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 13 : training on 1402998 raw words (1076955 effective words) took 5.8s, 184473 effective words/s
# Cumulative loss after epoch 13: 39517764.0
# Offset to previous loss: 1758940.0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 15.02% examples, 160282 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 32.03% examples, 168971 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 49.89% examples, 175564 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 66.20% examples, 175258 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 82.46% examples, 173966 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:EPOCH 14 - PROGRESS: at 99.28% examples, 174890 words/s, in_qsize 1, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 14 : training on 1402998 raw words (1077695 effective words) took 6.1s, 175619 effective words/s
# Cumulative loss after epoch 14: 41193700.0
# Offset to previous loss: 1675936.0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 15.02% examples, 159102 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 32.03% examples, 170917 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 49.16% examples, 171788 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 65.48% examples, 171861 words/s, in_qsize 3, out_qsize 2
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 82.52% examples, 173397 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:EPOCH 15 - PROGRESS: at 98.93% examples, 173856 words/s, in_qsize 2, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 15 : training on 1402998 raw words (1077268 effective words) took 6.2s, 173921 effective words/s
# Cumulative loss after epoch 15: 42981108.0
# Offset to previous loss: 1787408.0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 16.38% examples, 165320 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 32.76% examples, 168937 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 49.16% examples, 170873 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 65.50% examples, 171795 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 82.52% examples, 173042 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# INFO:gensim.models.base_any2vec:EPOCH 16 - PROGRESS: at 98.23% examples, 171749 words/s, in_qsize 3, out_qsize 0
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:EPOCH - 16 : training on 1402998 raw words (1078141 effective words) took 6.3s, 172476 effective words/s
# Cumulative loss after epoch 16: 44706840.0
# Offset to previous loss: 1725732.0
# INFO:gensim.models.base_any2vec:EPOCH 17 - PROGRESS: at 16.38% examples, 167947 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 17 - PROGRESS: at 33.48% examples, 172561 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 17 - PROGRESS: at 49.89% examples, 172493 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 17 - PROGRESS: at 66.20% examples, 171219 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 17 - PROGRESS: at 83.23% examples, 173110 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 44 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 50 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 17 : training on 1402998 raw words (1077384 effective words) took 6.2s, 174729 effective words/s
# Cumulative loss after epoch 17: 46532428.0
# Offset to previous loss: 1825588.0
# INFO:gensim.models.base_any2vec:EPOCH 18 - PROGRESS: at 15.71% examples, 163177 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 18 - PROGRESS: at 32.04% examples, 169104 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 18 - PROGRESS: at 49.16% examples, 171543 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 18 - PROGRESS: at 66.20% examples, 173296 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 18 - PROGRESS: at 83.22% examples, 173390 words/s, in_qsize 4, out_qsize 1
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 18 : training on 1402998 raw words (1077353 effective words) took 6.1s, 175641 effective words/s
# Cumulative loss after epoch 18: 48229680.0
# Offset to previous loss: 1697252.0
# INFO:gensim.models.base_any2vec:EPOCH 19 - PROGRESS: at 17.07% examples, 176415 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 19 - PROGRESS: at 33.48% examples, 173722 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 19 - PROGRESS: at 50.60% examples, 174034 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 19 - PROGRESS: at 67.61% examples, 174744 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 19 - PROGRESS: at 84.64% examples, 175637 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 19 : training on 1402998 raw words (1077156 effective words) took 6.1s, 176574 effective words/s
# Cumulative loss after epoch 19: 49951240.0
# Offset to previous loss: 1721560.0
# INFO:gensim.models.base_any2vec:EPOCH 20 - PROGRESS: at 15.66% examples, 168142 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 20 - PROGRESS: at 32.03% examples, 169578 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 20 - PROGRESS: at 49.89% examples, 172757 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 20 - PROGRESS: at 67.61% examples, 175410 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 20 - PROGRESS: at 83.93% examples, 175558 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 20 : training on 1402998 raw words (1077191 effective words) took 6.1s, 176265 effective words/s
# Cumulative loss after epoch 20: 51595028.0
# Offset to previous loss: 1643788.0
# INFO:gensim.models.base_any2vec:EPOCH 21 - PROGRESS: at 15.71% examples, 168579 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 21 - PROGRESS: at 32.76% examples, 170783 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 21 - PROGRESS: at 50.62% examples, 173901 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 21 - PROGRESS: at 67.61% examples, 174433 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 21 - PROGRESS: at 85.32% examples, 176888 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 21 : training on 1402998 raw words (1077809 effective words) took 6.1s, 177813 effective words/s
# Cumulative loss after epoch 21: 53176336.0
# Offset to previous loss: 1581308.0
# INFO:gensim.models.base_any2vec:EPOCH 22 - PROGRESS: at 16.38% examples, 170319 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 22 - PROGRESS: at 34.18% examples, 176401 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 22 - PROGRESS: at 52.08% examples, 178215 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 22 - PROGRESS: at 70.44% examples, 179868 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 22 - PROGRESS: at 86.73% examples, 179038 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 22 : training on 1402998 raw words (1077095 effective words) took 6.0s, 179787 effective words/s
# Cumulative loss after epoch 22: 54844648.0
# Offset to previous loss: 1668312.0
# INFO:gensim.models.base_any2vec:EPOCH 23 - PROGRESS: at 15.66% examples, 168383 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 23 - PROGRESS: at 32.76% examples, 175525 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 23 - PROGRESS: at 49.16% examples, 174050 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 23 - PROGRESS: at 66.20% examples, 175623 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 23 - PROGRESS: at 84.61% examples, 177980 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 23 : training on 1402998 raw words (1077153 effective words) took 6.0s, 180972 effective words/s
# Cumulative loss after epoch 23: 56512036.0
# Offset to previous loss: 1667388.0
# INFO:gensim.models.base_any2vec:EPOCH 24 - PROGRESS: at 17.07% examples, 177909 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 24 - PROGRESS: at 35.63% examples, 182352 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 24 - PROGRESS: at 52.75% examples, 180091 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 24 - PROGRESS: at 70.44% examples, 180508 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 24 - PROGRESS: at 88.21% examples, 180883 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 24 : training on 1402998 raw words (1077358 effective words) took 5.9s, 181733 effective words/s
# Cumulative loss after epoch 24: 58161684.0
# Offset to previous loss: 1649648.0
# INFO:gensim.models.base_any2vec:EPOCH 25 - PROGRESS: at 17.09% examples, 173586 words/s, in_qsize 6, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 25 - PROGRESS: at 35.63% examples, 179683 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 25 - PROGRESS: at 53.46% examples, 183497 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 25 - PROGRESS: at 69.74% examples, 181119 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 25 - PROGRESS: at 87.50% examples, 182256 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 25 : training on 1402998 raw words (1077372 effective words) took 5.9s, 182675 effective words/s
# Cumulative loss after epoch 25: 59780096.0
# Offset to previous loss: 1618412.0
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 16.38% examples, 175006 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 32.76% examples, 172543 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 49.88% examples, 175386 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 66.90% examples, 175444 words/s, in_qsize 6, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 26 - PROGRESS: at 83.95% examples, 177075 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 26 : training on 1402998 raw words (1077314 effective words) took 6.0s, 179663 effective words/s
# Cumulative loss after epoch 26: 61403980.0
# Offset to previous loss: 1623884.0
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 17.09% examples, 179557 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 34.18% examples, 181593 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 51.34% examples, 180687 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 68.31% examples, 180423 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 27 - PROGRESS: at 85.32% examples, 180284 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 50 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 43 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 27 : training on 1402998 raw words (1076956 effective words) took 5.9s, 181456 effective words/s
# Cumulative loss after epoch 27: 63043044.0
# Offset to previous loss: 1639064.0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 15.66% examples, 163495 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 32.76% examples, 173253 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 50.60% examples, 178316 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 67.61% examples, 179391 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 28 - PROGRESS: at 85.37% examples, 179198 words/s, in_qsize 6, out_qsize 1
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 28 : training on 1402998 raw words (1077609 effective words) took 5.9s, 181682 effective words/s
# Cumulative loss after epoch 28: 64680904.0
# Offset to previous loss: 1637860.0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 15.67% examples, 167846 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 33.48% examples, 178418 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 49.89% examples, 176004 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 66.90% examples, 177496 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 29 - PROGRESS: at 83.23% examples, 175500 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 29 : training on 1402998 raw words (1077783 effective words) took 6.1s, 176937 effective words/s
# Cumulative loss after epoch 29: 66339600.0
# Offset to previous loss: 1658696.0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 16.38% examples, 163534 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 33.48% examples, 170496 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 50.60% examples, 174145 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 66.90% examples, 173711 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 30 - PROGRESS: at 83.93% examples, 175275 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 30 : training on 1402998 raw words (1078157 effective words) took 6.1s, 175764 effective words/s
# Cumulative loss after epoch 30: 67129648.0
# Offset to previous loss: 790048.0
# INFO:gensim.models.base_any2vec:EPOCH 31 - PROGRESS: at 16.39% examples, 167110 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 31 - PROGRESS: at 34.16% examples, 172060 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 31 - PROGRESS: at 51.34% examples, 175805 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 31 - PROGRESS: at 67.59% examples, 175145 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 31 - PROGRESS: at 83.95% examples, 175102 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 31 : training on 1402998 raw words (1077375 effective words) took 6.1s, 176051 effective words/s
# Cumulative loss after epoch 31: 67167200.0
# Offset to previous loss: 37552.0
# INFO:gensim.models.base_any2vec:EPOCH 32 - PROGRESS: at 15.71% examples, 162472 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 32 - PROGRESS: at 33.48% examples, 174075 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 32 - PROGRESS: at 50.60% examples, 174391 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 32 - PROGRESS: at 67.59% examples, 175530 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 32 - PROGRESS: at 83.93% examples, 175453 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 32 : training on 1402998 raw words (1077043 effective words) took 6.1s, 176064 effective words/s
# Cumulative loss after epoch 32: 67208192.0
# Offset to previous loss: 40992.0
# INFO:gensim.models.base_any2vec:EPOCH 33 - PROGRESS: at 15.71% examples, 166609 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 33 - PROGRESS: at 32.04% examples, 168263 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 33 - PROGRESS: at 49.89% examples, 172895 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 33 - PROGRESS: at 66.20% examples, 171500 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 33 - PROGRESS: at 83.22% examples, 173343 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:EPOCH 33 - PROGRESS: at 100.00% examples, 174413 words/s, in_qsize 0, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 33 : training on 1402998 raw words (1077366 effective words) took 6.2s, 174103 effective words/s
# Cumulative loss after epoch 33: 67248624.0
# Offset to previous loss: 40432.0
# INFO:gensim.models.base_any2vec:EPOCH 34 - PROGRESS: at 15.71% examples, 164723 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 34 - PROGRESS: at 32.74% examples, 168726 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 34 - PROGRESS: at 49.89% examples, 171514 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 34 - PROGRESS: at 66.20% examples, 172450 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 34 - PROGRESS: at 82.52% examples, 172918 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:EPOCH 34 - PROGRESS: at 99.65% examples, 174168 words/s, in_qsize 1, out_qsize 1
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 50 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 34 : training on 1402998 raw words (1077492 effective words) took 6.2s, 174002 effective words/s
# Cumulative loss after epoch 34: 67287816.0
# Offset to previous loss: 39192.0
# INFO:gensim.models.base_any2vec:EPOCH 35 - PROGRESS: at 15.71% examples, 168911 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 35 - PROGRESS: at 32.76% examples, 170058 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 35 - PROGRESS: at 49.89% examples, 173884 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 35 - PROGRESS: at 67.59% examples, 177838 words/s, in_qsize 5, out_qsize 0
# ...
# Cumulative loss after epoch 38: 67458040.0
# Offset to previous loss: 43312.0
# INFO:gensim.models.base_any2vec:EPOCH 39 - PROGRESS: at 16.39% examples, 175131 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 39 - PROGRESS: at 34.16% examples, 180984 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 39 - PROGRESS: at 52.77% examples, 183094 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 39 - PROGRESS: at 71.13% examples, 185998 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 39 - PROGRESS: at 88.18% examples, 185337 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 39 : training on 1402998 raw words (1077404 effective words) took 5.8s, 185508 effective words/s
# Cumulative loss after epoch 39: 67501056.0
# Offset to previous loss: 43016.0
# INFO:gensim.models.base_any2vec:EPOCH 40 - PROGRESS: at 16.38% examples, 169585 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 40 - PROGRESS: at 33.48% examples, 170312 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 40 - PROGRESS: at 49.89% examples, 171422 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 40 - PROGRESS: at 66.90% examples, 171395 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 40 - PROGRESS: at 83.93% examples, 173757 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 40 : training on 1402998 raw words (1077781 effective words) took 6.2s, 173954 effective words/s
# Cumulative loss after epoch 40: 67544136.0
# Offset to previous loss: 43080.0
# INFO:gensim.models.base_any2vec:EPOCH 41 - PROGRESS: at 16.41% examples, 164133 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 41 - PROGRESS: at 34.18% examples, 174084 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 41 - PROGRESS: at 51.34% examples, 175939 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 41 - PROGRESS: at 68.31% examples, 175373 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 41 - PROGRESS: at 84.64% examples, 175171 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 41 : training on 1402998 raw words (1077889 effective words) took 6.2s, 175059 effective words/s
# Cumulative loss after epoch 41: 67587728.0
# Offset to previous loss: 43592.0
# INFO:gensim.models.base_any2vec:EPOCH 42 - PROGRESS: at 16.38% examples, 173152 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 42 - PROGRESS: at 33.48% examples, 172923 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 42 - PROGRESS: at 50.60% examples, 173204 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 42 - PROGRESS: at 67.61% examples, 174080 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 42 - PROGRESS: at 84.64% examples, 175866 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 42 : training on 1402998 raw words (1077447 effective words) took 6.1s, 176780 effective words/s
# Cumulative loss after epoch 42: 67631096.0
# Offset to previous loss: 43368.0
# INFO:gensim.models.base_any2vec:EPOCH 43 - PROGRESS: at 16.38% examples, 174971 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 43 - PROGRESS: at 33.48% examples, 175572 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 43 - PROGRESS: at 50.62% examples, 174943 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 43 - PROGRESS: at 67.59% examples, 176853 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 43 - PROGRESS: at 85.32% examples, 178369 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 43 : training on 1402998 raw words (1077751 effective words) took 6.0s, 179314 effective words/s
# Cumulative loss after epoch 43: 67673664.0
# Offset to previous loss: 42568.0
# INFO:gensim.models.base_any2vec:EPOCH 44 - PROGRESS: at 16.38% examples, 172673 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 44 - PROGRESS: at 33.48% examples, 176942 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 44 - PROGRESS: at 50.60% examples, 176083 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 44 - PROGRESS: at 67.59% examples, 176441 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 44 - PROGRESS: at 84.66% examples, 176603 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 44 : training on 1402998 raw words (1077037 effective words) took 6.0s, 178811 effective words/s
# Cumulative loss after epoch 44: 67719320.0
# Offset to previous loss: 45656.0
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:EPOCH 45 - PROGRESS: at 15.67% examples, 159905 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 45 - PROGRESS: at 32.76% examples, 170228 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 45 - PROGRESS: at 50.60% examples, 173997 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 45 - PROGRESS: at 68.32% examples, 176173 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 45 - PROGRESS: at 86.73% examples, 180027 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 45 : training on 1402998 raw words (1077817 effective words) took 6.0s, 181054 effective words/s
# Cumulative loss after epoch 45: 67762272.0
# Offset to previous loss: 42952.0
# INFO:gensim.models.base_any2vec:EPOCH 46 - PROGRESS: at 16.38% examples, 167833 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 46 - PROGRESS: at 33.48% examples, 174190 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 46 - PROGRESS: at 49.89% examples, 174885 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 46 - PROGRESS: at 66.20% examples, 175194 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 46 - PROGRESS: at 83.23% examples, 176639 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 46 : training on 1402998 raw words (1077265 effective words) took 6.1s, 177390 effective words/s
# Cumulative loss after epoch 46: 67806152.0
# Offset to previous loss: 43880.0
# INFO:gensim.models.base_any2vec:EPOCH 47 - PROGRESS: at 17.09% examples, 166480 words/s, in_qsize 5, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 47 - PROGRESS: at 34.18% examples, 174378 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 47 - PROGRESS: at 52.03% examples, 177220 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 47 - PROGRESS: at 69.74% examples, 180277 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 47 - PROGRESS: at 86.73% examples, 179990 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 47 : training on 1402998 raw words (1076849 effective words) took 5.9s, 181364 effective words/s
# Cumulative loss after epoch 47: 67849344.0
# Offset to previous loss: 43192.0
# INFO:gensim.models.base_any2vec:EPOCH 48 - PROGRESS: at 16.39% examples, 164415 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 48 - PROGRESS: at 34.18% examples, 174558 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 48 - PROGRESS: at 51.29% examples, 176111 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 48 - PROGRESS: at 68.31% examples, 177223 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 48 - PROGRESS: at 83.93% examples, 175388 words/s, in_qsize 4, out_qsize 1
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 49 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 48 : training on 1402998 raw words (1076755 effective words) took 6.1s, 177320 effective words/s
# Cumulative loss after epoch 48: 67891272.0
# Offset to previous loss: 41928.0
# INFO:gensim.models.base_any2vec:EPOCH 49 - PROGRESS: at 15.66% examples, 161038 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 49 - PROGRESS: at 33.47% examples, 168905 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 49 - PROGRESS: at 49.89% examples, 170662 words/s, in_qsize 4, out_qsize 1
# INFO:gensim.models.base_any2vec:EPOCH 49 - PROGRESS: at 66.90% examples, 173141 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 49 - PROGRESS: at 83.91% examples, 172532 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 46 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 47 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 49 : training on 1402998 raw words (1077437 effective words) took 6.2s, 174624 effective words/s
# Cumulative loss after epoch 49: 67934752.0
# Offset to previous loss: 43480.0
# INFO:gensim.models.base_any2vec:EPOCH 50 - PROGRESS: at 16.39% examples, 167802 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 50 - PROGRESS: at 33.48% examples, 173840 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 50 - PROGRESS: at 49.88% examples, 173808 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 50 - PROGRESS: at 66.90% examples, 175329 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.base_any2vec:EPOCH 50 - PROGRESS: at 84.64% examples, 177800 words/s, in_qsize 5, out_qsize 0
# DEBUG:gensim.models.base_any2vec:job loop exiting, total 141 jobs
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 45 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 2 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 1 more threads
# DEBUG:gensim.models.base_any2vec:worker exiting, processed 48 jobs
# INFO:gensim.models.base_any2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.base_any2vec:EPOCH - 50 : training on 1402998 raw words (1076887 effective words) took 6.1s, 177989 effective words/s
# Cumulative loss after epoch 50: 67980000.0
# Offset to previous loss: 45248.0
# INFO:gensim.models.base_any2vec:training on a 70149900 raw words (53866746 effective words) took 304.6s, 176864 effective words/s

# %%
# 한석규는 어떤 배우인가? 
# 원하는 단어가 어휘에 포함되었는지를 확인하고 싶을 땐, model.wv.vocab을 접근하면 됩니다.
if "최민식" in model.wv.vocab: 
  for word, score in model.wv.most_similar("최민식"):
    print(word, score)
else:
  raise ValueError("out of vocab")
# Out:
# 장승업 0.662408709526062
# 서영희 0.6593611240386963
# 김명민 0.6361349821090698
# 오달수 0.6103717684745789
# 한석규 0.6040471196174622
# 윤제문 0.6003439426422119
# 한예리 0.5888521671295166
# 박희순 0.5817450284957886
# 카가와 0.5810708999633789
# 김윤석 0.5804351568222046

# %%
# 어간 추출을 진행했기 때문에, "재밌다" 이라는 단어도 "재밌다"로 정규화되었을 것입니다.
if "재밌다" in model.wv.vocab:
  for word, score in model.wv.most_similar("재밌다"):
    print(word, score)
else:
  raise ValueError("out of vocab")
# Out:
# 재미있다 0.9427318572998047
# 재다 0.8392598628997803
# 재밋 0.7012117505073547
# 재밋어용 0.6994314193725586
# 재밋는듯 0.6895957589149475
# 쟈밋 0.6823498010635376
# 재밋었습니 0.6609838008880615
# 재밋어 0.6538165807723999
# 오호 0.6524783372879028
# 재밌슴 0.648705244064331
